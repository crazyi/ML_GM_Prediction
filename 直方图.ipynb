# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# 生成两组示例数据
df = pd.read_csv('重力数据2整体测试结果.csv')
value = df['value'].values
RNNprediction = df['RNN3-prediction'].values
RFprediction = df['RF2-prediction'].values
SVMprediction = df['SVM-prediction'].values
krigingprediction = df['kriging2-prediction'].values

# 计算两组数据的差值
RNNdifferences = RNNprediction - value
RFdifferences = RFprediction - value
SVMdifferences = SVMprediction - value
krigingdifferences = krigingprediction - value
# 设置宋体字体路径
font_path = 'C:/Windows/Fonts/simsun.ttc'  # 请根据您的系统字体路径进行修改
font_prop_1 = FontProperties(fname=font_path, size=12)
font_prop_2= FontProperties(family='Times New Roman')

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
font_prop = FontProperties(family='Times New Roman')
plt.rcParams['font.size'] = 15
# 创建一个新的图形
fig = plt.figure(figsize=(10, 8))

# 创建子图1，位置为(0, 0)
# plt.subplot(2, 2, 1)
plt.ylim(0, 350)

# 设置x轴范围为-15到20
plt.xlim(-40, 40)
plt.hist(RFdifferences, bins=500, alpha=0.5, color='b')
# plt.xlabel('Difference(mGal)')
plt.xlabel( 'Difference/mGal', fontproperties=font_prop_2,fontsize=20)

plt.ylabel('Frequency', fontproperties=font_prop_2,fontsize=20)
# plt.text(-39, 340, '(a)', fontsize=12, fontname='Times New Roman', verticalalignment='top', horizontalalignment='left')
# plt.tick_params(axis='both', which='both', bottom=False, top=False,   labelbottom=False)
# 创建子图2，位置为(0, 1)
# plt.subplot(2, 2, 2)
# 保存图像
plt.savefig('图10rf.png')

# 显示图形
plt.show()

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
font_prop = FontProperties(family='Times New Roman')
plt.rcParams['font.size'] = 15
fig = plt.figure(figsize=(10, 8))
plt.ylim(0, 350)

# 设置x轴范围为-15到20
plt.xlim(-40, 40)
plt.hist(RNNdifferences, bins=500, alpha=0.5, color='b')
# plt.xlabel('Difference(mGal)')
# plt.ylabel('Frequency')
plt.xlabel( 'Difference/mGal', fontproperties=font_prop_2,fontsize=20)

plt.ylabel('Frequency', fontproperties=font_prop_2,fontsize=20)
# plt.text(-39, 340, '(b)', fontsize=12, fontname='Times New Roman', verticalalignment='top', horizontalalignment='left')
# plt.tick_params(axis='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
# 创建子图3，位置为(1, 0)
# 保存图像
plt.savefig('图10rnn.png')

# 显示图形
plt.show()
# plt.subplot(2, 2, 3)
fig = plt.figure(figsize=(10, 8))
plt.ylim(0, 350)


# 设置x轴范围为-15到20
plt.xlim(-40, 40)
plt.hist(SVMdifferences, bins=500, alpha=0.5, color='b')
plt.xlabel( 'Difference/mGal', fontproperties=font_prop_2,fontsize=20)

plt.ylabel('Frequency', fontproperties=font_prop_2,fontsize=20)
# plt.text(-39, 340, '(c)', fontsize=12, fontname='Times New Roman', verticalalignment='top', horizontalalignment='left')
# 创建子图4，位置为(1, 1)
# plt.subplot(2, 2, 4)
# 保存图像
plt.savefig('图10svm.png')

# 显示图形
plt.show()
fig = plt.figure(figsize=(10, 8))
plt.ylim(0, 350)

# 设置x轴范围为-15到20
plt.xlim(-40, 40)
plt.hist(krigingdifferences, bins=500, alpha=0.5, color='b')
plt.xlabel( 'Difference/mGal', fontproperties=font_prop_2,fontsize=20)

plt.ylabel('Frequency', fontproperties=font_prop_2,fontsize=20)
# plt.text(-39, 340, '(d)', fontsize=12, fontname='Times New Roman', verticalalignment='top', horizontalalignment='left')
# plt.tick_params(axis='both',  top=False, left=False, right=False,  labelleft=False)
# 调整子图之间的间距
# plt.tight_layout()

# 保存图像
plt.savefig('图10kriging.png')

# 显示图形
plt.show()

# %%
# import matplotlib.pyplot as plt
# 
# # 创建一个新的图形
# fig = plt.figure(figsize=(10, 8))
# 
# # 创建子图1，位置为(0, 0)
# plt.subplot(2, 2, 1)
# plt.ylim(0, 350)
# 
# # 设置x轴范围为-15到20
# plt.xlim(-40, 40)
# plt.hist(RNNdifferences, bins=500, alpha=1, color='k')
# plt.xlabel('Difference')
# plt.ylabel('Frequency')
# plt.title('RNN')
# 
# # 创建子图2，位置为(0, 1)
# plt.subplot(2, 2, 2)
# plt.ylim(0, 350)
# 
# # 设置x轴范围为-15到20
# plt.xlim(-40, 40)
# plt.hist(RFdifferences, bins=500, alpha=1, color='k')
# plt.xlabel('Difference')
# plt.title('RF')
# 
# # 创建子图3，位置为(1, 0)
# plt.subplot(2, 2, 3)
# plt.ylim(0, 350)
# 
# # 设置x轴范围为-15到20
# plt.xlim(-40, 40)
# plt.hist(SVMdifferences, bins=500, alpha=1, color='k')
# plt.xlabel('Difference')
# plt.ylabel('Frequency')
# plt.title('SVM')
# 
# # 创建子图4，位置为(1, 1)
# plt.subplot(2, 2, 4)
# plt.ylim(0, 350)
# 
# # 设置x轴范围为-15到20
# plt.xlim(-40, 40)
# plt.hist(krigingdifferences, bins=500, alpha=1, color='k')
# plt.xlabel('Difference')
# plt.title('kriging')
# 
# # 调整子图之间的间距
# plt.tight_layout()
# 
# # 保存图像
# plt.savefig('2-2.png')
# 
# # 显示图形
# plt.show()

# %%
# 生成直方图
# 设置y轴范围为0到35
plt.ylim(0, 350)

# 设置x轴范围为-15到20
plt.xlim(-75, 75)

plt.hist(RNNdifferences, bins=500, alpha=1, color='k')
plt.xlabel('Difference')
# plt.ylabel('Frequency')
plt.title('RNN')
plt.grid(True)
plt.tick_params(axis='y', which='both', left=False, labelleft=False)
plt.savefig('RNN1.png') 
plt.show()

# %%
# 生成直方图
# 生成直方图
plt.ylim(0, 350)

# 设置x轴范围为-15到20
plt.xlim(-75, 75)

plt.hist(RFdifferences, bins=500, alpha=1, color='k')
plt.xlabel('Difference')
plt.ylabel('Frequency')
plt.title('RF')
plt.grid(True)
plt.savefig('RF1.png') 
plt.show()

# %%
# 生成直方图
# 设置y轴范围为0到35
plt.ylim(0, 350)

# 设置x轴范围为-15到20
plt.xlim(-75, 75)
# 生成直方图
plt.hist(SVMdifferences, bins=500, alpha=1, color='k')
plt.xlabel('Difference')
# plt.ylabel('Frequency')
plt.title('SVM')
plt.grid(True)
plt.tick_params(axis='y', which='both', left=False, labelleft=False)
plt.savefig('SVM1.png') 
plt.show()

# %%
# 生成直方图
# 设置y轴范围为0到35
plt.ylim(0, 350)

# 设置x轴范围为-15到20
plt.xlim(-75, 75)

# 生成直方图
plt.hist(krigingdifferences, bins=500, alpha=1, color='k')
plt.xlabel('Difference')
# plt.ylabel('Frequency')
plt.title('kriging')
plt.grid(True)
plt.tick_params(axis='y', which='both', left=False, labelleft=False)
plt.savefig('kriging1.png') 
plt.show()
